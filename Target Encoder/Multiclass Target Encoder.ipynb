# %% [markdown]
# # Multiclass Target Encoder

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Synthetic Dataset

# %%
np.random.seed(999)
target = list(np.random.randint(0, 3, 20))

# %%
genre = ["Romance", "Fantasy", "Nonfiction"]

# %%
np.random.seed(123)
genres = [genre[i] for i in np.random.randint(0, len(genre), 20)]

# %%
df = pd.DataFrame({"genre" : genres, "target" : target})

# %%
df
# Out:
#          genre  target
# 0   Nonfiction       0
# 1      Fantasy       0
# 2   Nonfiction       1
# 3   Nonfiction       1
# 4      Romance       0
# 5   Nonfiction       1
# 6   Nonfiction       1
# 7      Fantasy       0
# 8   Nonfiction       1
# 9      Fantasy       1
# 10  Nonfiction       0
# 11     Fantasy       0
# 12     Romance       0
# 13     Fantasy       1
# 14  Nonfiction       2
# 15     Fantasy       1
# 16     Romance       0
# 17  Nonfiction       2
# 18     Romance       2
# 19     Fantasy       2

# %% [markdown]
# ## Manual

# %% [markdown]
# ### Using the mean - wrong way
# Calculating only the posteriors

# %%
stats = df['target'].groupby(df['genre']).agg(['count', 'mean'])
stats
# Out:
#             count      mean
# genre
# Fantasy         7  0.714286
# Nonfiction      9  1.000000
# Romance         4  0.500000

# %%
df = df.join(stats.drop(columns = 'count'), on = 'genre', how = 'left').rename(columns = {'mean'  : 'genre_encoded_mean'})
df
# Out:
#          genre  target  genre_encoded_mean
# 0   Nonfiction       0            1.000000
# 1      Fantasy       0            0.714286
# 2   Nonfiction       1            1.000000
# 3   Nonfiction       1            1.000000
# 4      Romance       0            0.500000
# 5   Nonfiction       1            1.000000
# 6   Nonfiction       1            1.000000
# 7      Fantasy       0            0.714286
# 8   Nonfiction       1            1.000000
# 9      Fantasy       1            0.714286
# 10  Nonfiction       0            1.000000
# 11     Fantasy       0            0.714286
# 12     Romance       0            0.500000
# 13     Fantasy       1            0.714286
# 14  Nonfiction       2            1.000000
# 15     Fantasy       1            0.714286
# 16     Romance       0            0.500000
# 17  Nonfiction       2            1.000000
# 18     Romance       2            0.500000
# 19     Fantasy       2            0.714286

# %% [markdown]
# ### Sklearn Category Encoders - wrong way
#
# https://contrib.scikit-learn.org/category_encoders/targetencoder.html

# %%
from category_encoders import TargetEncoder

# %%
encoder = TargetEncoder()

# %%
df['genre_encoded_sklearn'] = encoder.fit_transform(df['genre'], df['target'])

# %%
df
# Out:
#          genre  target  genre_encoded_mean  genre_encoded_sklearn
# 0   Nonfiction       0            1.000000               0.999933
# 1      Fantasy       0            0.714286               0.714498
# 2   Nonfiction       1            1.000000               0.999933
# 3   Nonfiction       1            1.000000               0.999933
# 4      Romance       0            0.500000               0.514228
# 5   Nonfiction       1            1.000000               0.999933
# 6   Nonfiction       1            1.000000               0.999933
# 7      Fantasy       0            0.714286               0.714498
# 8   Nonfiction       1            1.000000               0.999933
# 9      Fantasy       1            0.714286               0.714498
# 10  Nonfiction       0            1.000000               0.999933
# 11     Fantasy       0            0.714286               0.714498
# 12     Romance       0            0.500000               0.514228
# 13     Fantasy       1            0.714286               0.714498
# 14  Nonfiction       2            1.000000               0.999933
# 15     Fantasy       1            0.714286               0.714498
# 16     Romance       0            0.500000               0.514228
# 17  Nonfiction       2            1.000000               0.999933
# 18     Romance       2            0.500000               0.514228
# 19     Fantasy       2            0.714286               0.714498

# %% [markdown]
# ### Using Probabilities
# Calculating only the posteriors, by using conditional probabilities

# %% [raw]
# df['target'] = df['target'].replace({0: 'apple', 1: "banana", 2: 'orange'})

# %%
df = df.drop(columns = ['genre_encoded_mean', 'genre_encoded_sklearn'])

# %%
categories = df['genre'].unique()
targets = df['target'].unique()
cat_list = []
for cat in categories:
    aux_dict = {}
    aux_dict['category'] = cat
    aux_df = df[df['genre'] == cat]
    counts = aux_df['target'].value_counts()
    aux_dict['count'] = sum(counts)
    for t in targets:
        aux_dict['target_' + str(t)] = counts[t] if t in counts.keys() else 0
    cat_list.append(aux_dict)

# %%
cat_list = pd.DataFrame(cat_list)

# %%
for t in targets:
    cat_list['genre_encoded_prob_target_' + str(t)] = cat_list['target_' + str(t)] / cat_list['count']

# %%
cat_list
# Out:
#      category  count  target_0  target_1  target_2  \
# 0  Nonfiction      9         2         5         2
# 1     Fantasy      7         3         3         1
# 2     Romance      4         3         0         1
#
#    genre_encoded_prob_target_0  genre_encoded_prob_target_1  \
# 0                     0.222222                     0.555556
# 1                     0.428571                     0.428571
# 2                     0.750000                     0.000000
#
#    genre_encoded_prob_target_2
# 0                     0.222222
# 1                     0.142857
# 2                     0.250000

# %%
df = df.join(cat_list.drop(columns = (['count'] + ['target_' + str(t) for t in targets])).set_index('category'), on = 'genre', how = 'left')
df
# Out:
#          genre  target  genre_encoded_prob_target_0  \
# 0   Nonfiction       0                     0.222222
# 1      Fantasy       0                     0.428571
# 2   Nonfiction       1                     0.222222
# 3   Nonfiction       1                     0.222222
# 4      Romance       0                     0.750000
# 5   Nonfiction       1                     0.222222
# 6   Nonfiction       1                     0.222222
# 7      Fantasy       0                     0.428571
# 8   Nonfiction       1                     0.222222
# 9      Fantasy       1                     0.428571
# 10  Nonfiction       0                     0.222222
# 11     Fantasy       0                     0.428571
# 12     Romance       0                     0.750000
# 13     Fantasy       1                     0.428571
# 14  Nonfiction       2                     0.222222
# 15     Fantasy       1                     0.428571
# 16     Romance       0                     0.750000
# 17  Nonfiction       2                     0.222222
# 18     Romance       2                     0.750000
# 19     Fantasy       2                     0.428571
#
#     genre_encoded_prob_target_1  genre_encoded_prob_target_2
# 0                      0.555556                     0.222222
# 1                      0.428571                     0.142857
# 2                      0.555556                     0.222222
# 3                      0.555556                     0.222222
# 4                      0.000000                     0.250000
# 5                      0.555556                     0.222222
# 6                      0.555556                     0.222222
# 7                      0.428571                     0.142857
# 8                      0.555556                     0.222222
# 9                      0.428571                     0.142857
# 10                     0.555556                     0.222222
# 11                     0.428571                     0.142857
# 12                     0.000000                     0.250000
# 13                     0.428571                     0.142857
# 14                     0.555556                     0.222222
# 15                     0.428571                     0.142857
# 16                     0.000000                     0.250000
# 17                     0.555556                     0.222222
# 18                     0.000000                     0.250000
# 19                     0.428571                     0.142857

# %% [markdown]
# ### Using the library - right way

# %%
from category_encoders import TargetEncoder

# %%
targets = df['target'].unique()
for t in targets:
    target_aux = df['target'].apply(lambda x: 1 if x == t else 0)
    encoder = TargetEncoder()
    df['genre_encoded_sklearn_target_' + str(t)] = encoder.fit_transform(df['genre'], target_aux)

# %%
df
# Out:
#          genre  target  genre_encoded_prob_target_0  \
# 0   Nonfiction       0                     0.222222
# 1      Fantasy       0                     0.428571
# 2   Nonfiction       1                     0.222222
# 3   Nonfiction       1                     0.222222
# 4      Romance       0                     0.750000
# 5   Nonfiction       1                     0.222222
# 6   Nonfiction       1                     0.222222
# 7      Fantasy       0                     0.428571
# 8   Nonfiction       1                     0.222222
# 9      Fantasy       1                     0.428571
# 10  Nonfiction       0                     0.222222
# 11     Fantasy       0                     0.428571
# 12     Romance       0                     0.750000
# 13     Fantasy       1                     0.428571
# 14  Nonfiction       2                     0.222222
# 15     Fantasy       1                     0.428571
# 16     Romance       0                     0.750000
# 17  Nonfiction       2                     0.222222
# 18     Romance       2                     0.750000
# 19     Fantasy       2                     0.428571
#
#     genre_encoded_prob_target_1  genre_encoded_prob_target_2  \
# 0                      0.555556                     0.222222
# 1                      0.428571                     0.142857
# 2                      0.555556                     0.222222
# 3                      0.555556                     0.222222
# 4                      0.000000                     0.250000
# 5                      0.555556                     0.222222
# 6                      0.555556                     0.222222
# 7                      0.428571                     0.142857
# 8                      0.555556                     0.222222
# 9                      0.428571                     0.142857
# 10                     0.555556                     0.222222
# 11                     0.428571                     0.142857
# 12                     0.000000                     0.250000
# 13                     0.428571                     0.142857
# 14                     0.555556                     0.222222
# 15                     0.428571                     0.142857
# 16                     0.000000                     0.250000
# 17                     0.555556                     0.222222
# 18                     0.000000                     0.250000
# 19                     0.428571                     0.142857
#
#     genre_encoded_sklearn_target_0  genre_encoded_sklearn_target_1  \
# 0                         0.222282                        0.555503
# 1                         0.428501                        0.428501
# 2                         0.222282                        0.555503
# 3                         0.222282                        0.555503
# 4                         0.733401                        0.018970
# 5                         0.222282                        0.555503
# 6                         0.222282                        0.555503
# 7                         0.428501                        0.428501
# 8                         0.222282                        0.555503
# 9                         0.428501                        0.428501
# 10                        0.222282                        0.555503
# 11                        0.428501                        0.428501
# 12                        0.733401                        0.018970
# 13                        0.428501                        0.428501
# 14                        0.222282                        0.555503
# 15                        0.428501                        0.428501
# 16                        0.733401                        0.018970
# 17                        0.222282                        0.555503
# 18                        0.733401                        0.018970
# 19                        0.428501                        0.428501
#
#     genre_encoded_sklearn_target_2
# 0                         0.222215
# 1                         0.142998
# 2                         0.222215
# 3                         0.222215
# 4                         0.247629
# 5                         0.222215
# 6                         0.222215
# 7                         0.142998
# 8                         0.222215
# 9                         0.142998
# 10                        0.222215
# 11                        0.142998
# 12                        0.247629
# 13                        0.142998
# 14                        0.222215
# 15                        0.142998
# 16                        0.247629
# 17                        0.222215
# 18                        0.247629
# 19                        0.142998

# %% [markdown]
# ### Using the mean - right way

# %%
from category_encoders import TargetEncoder

# %%
targets = df['target'].unique()
for t in targets:
    df['target_' + str(t)] = df['target'].apply(lambda x: 1 if x == t else 0)
    stats = df['target_' + str(t)].groupby(df['genre']).agg(['mean'])
    df = df.join(stats, on = 'genre', how = 'left').rename(columns = {'mean'  : 'genre_encoded_mean_target_' + str(t)})
    df = df.drop(columns = ['target_' + str(t)])

# %%
df
# Out:
#          genre  target  genre_encoded_prob_target_0  \
# 0   Nonfiction       0                     0.222222
# 1      Fantasy       0                     0.428571
# 2   Nonfiction       1                     0.222222
# 3   Nonfiction       1                     0.222222
# 4      Romance       0                     0.750000
# 5   Nonfiction       1                     0.222222
# 6   Nonfiction       1                     0.222222
# 7      Fantasy       0                     0.428571
# 8   Nonfiction       1                     0.222222
# 9      Fantasy       1                     0.428571
# 10  Nonfiction       0                     0.222222
# 11     Fantasy       0                     0.428571
# 12     Romance       0                     0.750000
# 13     Fantasy       1                     0.428571
# 14  Nonfiction       2                     0.222222
# 15     Fantasy       1                     0.428571
# 16     Romance       0                     0.750000
# 17  Nonfiction       2                     0.222222
# 18     Romance       2                     0.750000
# 19     Fantasy       2                     0.428571
#
#     genre_encoded_prob_target_1  genre_encoded_prob_target_2  \
# 0                      0.555556                     0.222222
# 1                      0.428571                     0.142857
# 2                      0.555556                     0.222222
# 3                      0.555556                     0.222222
# 4                      0.000000                     0.250000
# 5                      0.555556                     0.222222
# 6                      0.555556                     0.222222
# 7                      0.428571                     0.142857
# 8                      0.555556                     0.222222
# 9                      0.428571                     0.142857
# 10                     0.555556                     0.222222
# 11                     0.428571                     0.142857
# 12                     0.000000                     0.250000
# 13                     0.428571                     0.142857
# 14                     0.555556                     0.222222
# 15                     0.428571                     0.142857
# 16                     0.000000                     0.250000
# 17                     0.555556                     0.222222
# 18                     0.000000                     0.250000
# 19                     0.428571                     0.142857
#
#     genre_encoded_sklearn_target_0  genre_encoded_sklearn_target_1  \
# 0                         0.222282                        0.555503
# 1                         0.428501                        0.428501
# 2                         0.222282                        0.555503
# 3                         0.222282                        0.555503
# 4                         0.733401                        0.018970
# 5                         0.222282                        0.555503
# 6                         0.222282                        0.555503
# 7                         0.428501                        0.428501
# 8                         0.222282                        0.555503
# 9                         0.428501                        0.428501
# 10                        0.222282                        0.555503
# 11                        0.428501                        0.428501
# 12                        0.733401                        0.018970
# 13                        0.428501                        0.428501
# 14                        0.222282                        0.555503
# 15                        0.428501                        0.428501
# 16                        0.733401                        0.018970
# 17                        0.222282                        0.555503
# 18                        0.733401                        0.018970
# 19                        0.428501                        0.428501
#
#     genre_encoded_sklearn_target_2  genre_encoded_mean_target_0  \
# 0                         0.222215                     0.222222
# 1                         0.142998                     0.428571
# 2                         0.222215                     0.222222
# 3                         0.222215                     0.222222
# 4                         0.247629                     0.750000
# 5                         0.222215                     0.222222
# 6                         0.222215                     0.222222
# 7                         0.142998                     0.428571
# 8                         0.222215                     0.222222
# 9                         0.142998                     0.428571
# 10                        0.222215                     0.222222
# 11                        0.142998                     0.428571
# 12                        0.247629                     0.750000
# 13                        0.142998                     0.428571
# 14                        0.222215                     0.222222
# 15                        0.142998                     0.428571
# 16                        0.247629                     0.750000
# 17                        0.222215                     0.222222
# 18                        0.247629                     0.750000
# 19                        0.142998                     0.428571
#
#     genre_encoded_mean_target_1  genre_encoded_mean_target_2
# 0                      0.555556                     0.222222
# 1                      0.428571                     0.142857
# 2                      0.555556                     0.222222
# 3                      0.555556                     0.222222
# 4                      0.000000                     0.250000
# 5                      0.555556                     0.222222
# 6                      0.555556                     0.222222
# 7                      0.428571                     0.142857
# 8                      0.555556                     0.222222
# 9                      0.428571                     0.142857
# 10                     0.555556                     0.222222
# 11                     0.428571                     0.142857
# 12                     0.000000                     0.250000
# 13                     0.428571                     0.142857
# 14                     0.555556                     0.222222
# 15                     0.428571                     0.142857
# 16                     0.000000                     0.250000
# 17                     0.555556                     0.222222
# 18                     0.000000                     0.250000
# 19                     0.428571                     0.142857
